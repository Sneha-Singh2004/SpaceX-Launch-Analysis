# %%
import pandas as pd

# %%
df = pd.read_csv("../data/spacex_launch_data.csv")

df.head()
# Out:
#        static_fire_date_utc  static_fire_date_unix    net  window  \
# 0  2006-03-17T00:00:00.000Z           1.142554e+09  False     0.0
# 1                       NaN                    NaN  False     0.0
# 2                       NaN                    NaN  False     0.0
# 3  2008-09-20T00:00:00.000Z           1.221869e+09  False     0.0
# 4                       NaN                    NaN  False     0.0
#
#                      rocket success  \
# 0  5e9d0d95eda69955f709d1eb   False
# 1  5e9d0d95eda69955f709d1eb   False
# 2  5e9d0d95eda69955f709d1eb   False
# 3  5e9d0d95eda69955f709d1eb    True
# 4  5e9d0d95eda69955f709d1eb    True
#
#                                             failures  \
# 0  [{'time': 33, 'altitude': None, 'reason': 'mer...
# 1  [{'time': 301, 'altitude': 289, 'reason': 'har...
# 2  [{'time': 140, 'altitude': 35, 'reason': 'resi...
# 3                                                 []
# 4                                                 []
#
# ...

# %%
df = df[[
    'name',
    'date_utc',
    'success',
    'rocket',
    'launchpad',
    'flight_number'
]]

df.head()
# Out:
#           name                  date_utc success                    rocket  \
# 0    FalconSat  2006-03-24T22:30:00.000Z   False  5e9d0d95eda69955f709d1eb
# 1      DemoSat  2007-03-21T01:10:00.000Z   False  5e9d0d95eda69955f709d1eb
# 2  Trailblazer  2008-08-03T03:34:00.000Z   False  5e9d0d95eda69955f709d1eb
# 3       RatSat  2008-09-28T23:15:00.000Z    True  5e9d0d95eda69955f709d1eb
# 4     RazakSat  2009-07-13T03:35:00.000Z    True  5e9d0d95eda69955f709d1eb
#
#                   launchpad  flight_number
# 0  5e9e4502f5090995de566f86              1
# 1  5e9e4502f5090995de566f86              2
# 2  5e9e4502f5090995de566f86              3
# 3  5e9e4502f5090995de566f86              4
# 4  5e9e4502f5090995de566f86              5

# %%
df['success'] = df['success'].fillna(0)
df['success'] = df['success'].astype(int)

# %%
df['success'] = df['success'].fillna(0).astype(int)

# %%
df['success'].value_counts()
# Out:
# success
# 1    181
# 0     24
# Name: count, dtype: int64

# %%
df.to_csv("../data/cleaned_spacex_data.csv", index=False)
