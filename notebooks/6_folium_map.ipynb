# %%
import pandas as pd
import folium

df = pd.read_csv("../data/cleaned_spacex_data.csv")

# Launch site coordinates (example)
launch_sites = {
    "CCAFS SLC 40": [28.5623, -80.5774],
    "KSC LC 39A": [28.573255, -80.646895],
    "VAFB SLC 4E": [34.6328, -120.6108]
}

m = folium.Map(location=[28.5, -80.5], zoom_start=4)

for site, coords in launch_sites.items():
    folium.Marker(
        location=coords,
        popup=site
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_694e6f7ee484064f5de9854f4eaf1d31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_694e6f7ee484064f5de9854f4eaf1d31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_694e6f7ee484064f5de9854f4eaf1d31 = L.map(
#                 &quot;map_694e6f7ee484064f5de9854f4eaf1d31&quot;,
#                 {
#                     center: [28.5, -80.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_efcea5a9fd890077bf7dc3c10582e7a0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_efcea5a9fd890077bf7dc3c10582e7a0.addTo(map_694e6f7ee484064f5de9854f4eaf1d31);
#
#
#             var marker_a4f051a3331cc18be8a158395c192155 = L.marker(
#                 [28.5623, -80.5774],
#                 {
# }
#             ).addTo(map_694e6f7ee484064f5de9854f4eaf1d31);
#
#
#         var popup_33c375be9c69e90a7564aa6a4a8a9271 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c95b37e2e03c0782c02343b0151481a7 = $(`&lt;div id=&quot;html_c95b37e2e03c0782c02343b0151481a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC 40&lt;/div&gt;`)[0];
#                 popup_33c375be9c69e90a7564aa6a4a8a9271.setContent(html_c95b37e2e03c0782c02343b0151481a7);
#
#
#
#         marker_a4f051a3331cc18be8a158395c192155.bindPopup(popup_33c375be9c69e90a7564aa6a4a8a9271)
#         ;
#
#
#
#
#             var marker_dd3498f1c1dd23605efe46f404ec8e47 = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(map_694e6f7ee484064f5de9854f4eaf1d31);
#
#
#         var popup_19909d9ff2398b21386b4cc4d35e95b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f8e05077a43917d8c366b22f0cc9c60 = $(`&lt;div id=&quot;html_6f8e05077a43917d8c366b22f0cc9c60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC 39A&lt;/div&gt;`)[0];
#                 popup_19909d9ff2398b21386b4cc4d35e95b7.setContent(html_6f8e05077a43917d8c366b22f0cc9c60);
#
#
#
#         marker_dd3498f1c1dd23605efe46f404ec8e47.bindPopup(popup_19909d9ff2398b21386b4cc4d35e95b7)
#         ;
#
#
#
#
#             var marker_28398976ff9370237a5e0e63ec489a83 = L.marker(
#                 [34.6328, -120.6108],
#                 {
# }
#             ).addTo(map_694e6f7ee484064f5de9854f4eaf1d31);
#
#
#         var popup_6289254388bb0a4832750b4291a8b53f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0dea0447959e791e072ef472cba6ba9 = $(`&lt;div id=&quot;html_f0dea0447959e791e072ef472cba6ba9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC 4E&lt;/div&gt;`)[0];
#                 popup_6289254388bb0a4832750b4291a8b53f.setContent(html_f0dea0447959e791e072ef472cba6ba9);
#
#
#
#         marker_28398976ff9370237a5e0e63ec489a83.bindPopup(popup_6289254388bb0a4832750b4291a8b53f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
